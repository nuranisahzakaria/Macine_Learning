# %%
from sklearn.preprocessing import MinMaxScaler
data = [ [12000000, 33], [35000000, 45], [4000000, 23], [65000000, 26], [9000000,29] ]

# %%
scaler = MinMaxScaler()
scaler.fit(data)
# Out:
# MinMaxScaler()

# %%
print(scaler.transform(data))
# Out:
# [[0.13114754 0.45454545]
#  [0.50819672 1.        ]
#  [0.         0.        ]
#  [1.         0.13636364]
#  [0.08196721 0.27272727]]
